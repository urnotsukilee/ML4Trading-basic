# %% [markdown]
# # Import libraries

# %%
import matplotlib as plot
import numpy as np
import pandas as pd
from sklearn import preprocessing as pre

# %% [markdown]
# # Import Data

# %%
#This file store the meta message of all stocks and etfs, only use stocks in the project
stocks_meta = pd.read_csv("./symbols_valid_meta.csv")
stocks_meta = stocks_meta[stocks_meta["ETF"]=="Y"].sort_values(by = ["Symbol"])
stocks_meta
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 2                Y   AAAU                       Perth Mint Physical Gold ETF
# 4                Y   AADR                AdvisorShares Dorsey Wright ADR ETF
# 16               Y   AAXJ  iShares MSCI All Country Asia ex Japan Index Fund
# 24               Y   ABEQ                         Absolute Core Strategy ETF
# 45               Y   ACES                              ALPS Clean Energy ETF
# ...            ...    ...                                                ...
# 8017             Y    ZIG                                 The Acquirers Fund
# 8027             Y   ZJPN                           SPDR Solactive Japan ETF
# 8031             Y   ZMLP        Direxion Zacks MLP High Income Index Shares
# 8036             Y   ZROZ  PIMCO 25  Year Zero Coupon U.S. Treasury Index...
# 8039             Y    ZSL                        ProShares UltraShort Silver
#
# ...

# %%
A_meta = stocks_meta[stocks_meta["Symbol"]=="A"]
A_meta
##没有symbol为A的stock，csv名是什么意思
# Out:
# Empty DataFrame
# Columns: [Nasdaq Traded, Symbol, Security Name, Listing Exchange, Market Category, ETF, Round Lot Size, Test Issue, Financial Status, CQS Symbol, NASDAQ Symbol, NextShares]
# Index: []
